# %% [markdown]
# * Hit shift-enter in each of these "cells" until the image is produced

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from matplotlib.cm import *

# %%
figure(figsize=(8,10))
M=randint(0,255,(10,8))
imshow(M,cmap=jet)  # <==== change this line for a colormap


grid(True,color='k',lw=2)

gca().set_xticks(arange(8)+.5)
gca().set_yticks(arange(10)+.5)
gca().set_xticklabels([])
gca().set_yticklabels([])
# Out:
# []
